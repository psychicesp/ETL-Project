# %%
#Dependencies
from wordcloud import WordCloud, STOPWORDS 
from matplotlib import pyplot as plt
import pandas as pd

# %%
# Reference to CSV and reading CSV into Pandas DataFrame
csv_path = "../Full_Ramen.csv"
ramen_df = pd.read_csv(csv_path)
ramen_df.head(1)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Review_ID  \
# 0           0             0     3473.0
#
#                                                  URL    Brand  \
# 0  https://www.theramenrater.com/2020/04/05/3473-...  MyKuali
#
#                    Variety Style   Country Stars Top Ten  \
# 0  White Fish Broth Noodle  Pack  Malaysia     5     NaN
#
#                                                Blurb
# 0  Finished (click to enlarge). Added Dodo shrimp...

# %%
ramen_country_count_df = ramen_df["Country"].value_counts()
#ramen_country_count_df

# %%
#Country corrections
corrections = {
   'Country': {
      'USA': 'United States',
      'UK': 'United Kingdom',
      'Souh Korea': 'South Korea',
      'Dubai':'United Arab Emirates',
      'Sarawak':'Malaysia'}
}

ramen_df.replace(corrections, regex=True, inplace=True)

#print(ramen_df)

# %%
ramen_country_count_df = ramen_df["Country"].value_counts()
#ramen_df.head()

# %%
#Set Continent List Manually
North_America = ['United States','Canada','Mexico']
South_America = ['Brazil','Peru','Colombia']
Australia = ['Australia']
Oceania = ['Fiji','New Zealand']
Africa = ['Ghana','Nigeria']
Europe = ['Finland','France','Germany','Holland','Italy','Poland','Spain','Sweden','United Kingdom','Portugal','Hungary','Netherlands','Estonia','Ukraine']
Asia = ['Bangladesh','Cambodia','China','India','Indonesia','Israel','Japan','Malaysia','Myanmar','Nepal','Pakistan','Philippines','Phlippines','Singapore','South Korea','Taiwan','Thailand','Hong Kong','Russia','Vietnam']


# Add Continent column
ramen_df = ramen_df.copy()
ramen_df['Continent'] = ''

for i in ramen_df.index:
    
    if ramen_df['Country'][i] in North_America:
        ramen_df.loc[i,'Continent'] = 'North America'
        
    if ramen_df['Country'][i] in South_America:
        ramen_df.loc[i,'Continent'] = 'South America'
    
    if ramen_df['Country'][i] in Australia:
        ramen_df.loc[i,'Continent'] = 'Australia'
        
    if ramen_df['Country'][i] in Oceania:
        ramen_df.loc[i,'Continent'] = 'Oceania'
        
    if ramen_df['Country'][i] in Africa:
        ramen_df.loc[i,'Continent'] = 'Africa'
        
    if ramen_df['Country'][i] in Europe:
        ramen_df.loc[i,'Continent'] = 'Europe'
    
    if ramen_df['Country'][i] in Asia:
        ramen_df.loc[i,'Continent'] = 'Asia'
        
ramen_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Review_ID  \
# 0           0             0     3473.0
# 1           1             1     3472.0
# 2           2             2     3471.0
# 3           3             3     3470.0
# 4           4             4     3469.0
#
#                                                  URL    Brand  \
# 0  https://www.theramenrater.com/2020/04/05/3473-...  MyKuali
# 1  https://www.theramenrater.com/2020/04/05/3472-...  MyKuali
# 2  https://www.theramenrater.com/2020/04/05/3471-...  Ve Wong
# 3  https://www.theramenrater.com/2020/04/04/3470-...    Myojo
# 4  https://www.theramenrater.com/2020/04/03/3469-...  Mykuali
#
#                                              Variety Style   Country Stars  \
# 0                            White Fish Broth Noodle  Pack  Malaysia     5
# 1             Penang White Curry Noodle (New Recipe)  Pack  Malaysia     5
# 2  Instant Oriental Noodles Soup Chinese Herb - G...  Pack    Taiwan  3.75
# 3                    Ippeichan Rich & Sweet Yakisoba  Tray     Japan     5
# 4          Penang Hokkien Prawn Rice Vermicelli Soup  Bowl  Malaysia     5
#
#   Top Ten                                              Blurb Continent
# 0     NaN  Finished (click to enlarge). Added Dodo shrimp...      Asia
# 1     NaN  Finished (click to enlarge). Added tofu, egg, ...      Asia
# 2     NaN  Finished (click to enlarge). Added spring onio...      Asia
# 3     NaN  Finished (click to enlarge). Added Salad Cosmo...      Asia
# 4     NaN  Finished (click to enlarge). Added shrimp, egg...      Asia

# %%
# website used for code (https://www.geeksforgeeks.org/generating-word-cloud-python/)
for val in ramen_df.Blurb:
    val= str(val)
    
    tokens= val.split()
    
    for i in range(len(Blurb)):
        Blurb[i] = Blurbs[i].lower()
    comment_words += " ".join(Blurbs)+ " "
    
wordcloud = WorldCloud(width = 800, height = 800, 
                      background_color ='white',
                      stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-62d0b8de7fb1> in <module>
#       4     tokens= val.split()
#       5
# ----> 6     for i in range(len(Blurb)):
#       7         Blurb[i] = Blurbs[i].lower()
#       8     comment_words += " ".join(Blurbs)+ " "
#
# NameError: name 'Blurb' is not defined
